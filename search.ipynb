# %%
l = 0 #переменная для подсчета иттерация линейного поиска
b = 0 #переменная для подсчета иттерация бинарного поиска
from random import randint
list_2=[]#создаем пустой список
q = 0#переменная для количества иттераций при выборочной сортировке
for i in range (0, 100): #цикл для добавления элементов в список
    b = randint(1, 1_000_000) #выбираем число
    list_2.append(b) #добавляем его в список
stop_flag=True
while (stop_flag is True):
    stop_flag=False
    for i in range (0,len(list_2)-1):
        if list_2[i]>list_2[i+1]:
            a=list_2[i]
            list_2[i]=list_2[i+1]
            list_2[i+1]=a
            stop_flag=True
list_2
# Out:
# [7149,
#  16311,
#  19128,
#  22902,
#  25453,
#  26015,
#  31390,
#  37725,
#  37786,
#  38172,
#  39685,
#  71540,
#  87955,
#  101015,
#  116989,
#  132515,
#  139880,
#  145949,
#  165447,
#  170610,
#  180820,
#  189922,
#  197504,
#  197654,
#  210151,
#  217289,
#  218558,
#  222767,
#  230895,
#  245380,
#  278949,
#  283849,
#  296852,
#  297659,
#  307462,
#  320645,
#  331120,
#  362807,
#  385074,
#  404673,
#  419958,
#  423380,
#  440016,
#  442675,
#  451868,
#  472059,
#  480354,
#  487656,
#  490910,
#  493266,
#  493852,
#  507729,
#  508472,
#  530994,
#  532922,
#  551283,
#  569405,
#  569626,
#  596618,
#  660686,
#  667170,
#  679118,
#  679373,
#  679949,
#  683014,
#  689111,
#  690413,
#  695285,
#  698960,
#  699234,
#  699473,
#  700054,
#  707880,
#  717384,
#  721649,
#  750519,
#  764719,
#  777913,
#  780842,
#  821918,
#  832122,
#  849157,
#  874230,
#  877749,
#  890192,
#  896733,
#  898601,
#  900007,
#  910580,
#  916815,
#  927378,
#  940323,
# ...

# %% [markdown]
# ЛИНЕЙНЫЙ ПОИСК

# %%
el=element=101015

flag = False# Создаем переменную, чтобы понять, найден ли элемент

for i in range(len(list_2)):#Перебираем все элементы
    if list_2[i]==el:#если введенное числа равно какому-то элементу из списка
        print(i)
        flag = True#переставляем переменную в позицию Тру, чтобы показать, что элемент найден
        break#прерываем цикл

if flag == False:#если элемент найден не будет, то мы выведем
    print('element not founded')
# Out:
# 13

# %% [markdown]
# БИНАРНЫЙ ПОИСК

# %%
w = 101015

p= 0#первый индекс
l = len(list_2)-1#последний
index = -1
while (p <= l) and (index == -1): #цикл будет выполняться пока первый индекст будет меньше или равен последнему или мы не найдем нужный элемент
    mid = (p+l)//2 #находим центральный элемент
    if list_2[mid] == w:#если введенное число равно центральному элементу
        index = mid #то мы присваиваем переменной значение индекса этого элемента
    else:
        if a<list_2[mid]:#если меньше
            l = mid -1#мы обрезаем значения справа наполовину
        else:#если больше
            p = mid +1#мы обрезаем значенния слева наполовину
    b += 1 #добавляем одну иттерация
#цикл будет работать, пока введенное числе не будет равно какому-либо новую централному элементу

if index == -1: #если индекс будет равен -1, это будет означать, что мы не нашли элемент
    print(f'Элемент {w} не найден в списке')

else: 
    print(f'Элемент {w} находится в списке на месте c индексом {index}')
    print(f'Для бинарного поиска понадобилось {b} иттераций')
# Out:
# Элемент 101015 находится в списке на месте c индексом 13
# Для бинарного поиска понадобилось 25487 иттераций
